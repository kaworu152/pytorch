# %%
# !nvidia-smi
# Out:
# Thu Sep 24 14:01:59 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 591.86                 Driver Version: 591.86         CUDA Version: 13.1     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3080      WDDM  |   00000000:09:00.0  On |                  N/A |
# | 36%   48C    P3             75W /  320W |    1425MiB /  10240MiB |     13%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            5444    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           18048    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           18440    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           26880    C+G   ...ram Files\Listary\Listary.exe      N/A      |
# |    0   N/A  N/A           27776    C+G   ...lpaper_engine\wallpaper32.exe      N/A      |
# |    0   N/A  N/A           29140    C+G   ...IA App\CEF\NVIDIA Overlay.exe      N/A      |
# |    0   N/A  N/A           30308    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           30536    C+G   ...yb3d8bbwe\WindowsTerminal.exe      N/A      |
# |    0   N/A  N/A           34856    C+G   ...zer Central\Razer Central.exe      N/A      |
# |    0   N/A  N/A           35456    C+G   ...h_cw5n1h2txyewy\SearchApp.exe      N/A      |
# |    0   N/A  N/A           36708    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           36844    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           37812    C+G   ...26wp6bftszj\TranslucentTB.exe      N/A      |
# |    0   N/A  N/A           39180    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
from torch import nn

torch.device('cpu'), torch.device('cuda'), torch.device('cuda:1')
# Out:
# (device(type='cpu'), device(type='cuda'), device(type='cuda', index=1))

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
def try_gpu(i=0):  #@save
    """如果存在，则返回gpu(i)，否则返回cpu()"""
    if torch.cuda.device_count() >= i + 1:
        return torch.device(f'cuda:{i}')
    return torch.device('cpu')

def try_all_gpus():  #@save
    """返回所有可用的GPU，如果没有GPU，则返回[cpu(),]"""
    devices = [torch.device(f'cuda:{i}')
             for i in range(torch.cuda.device_count())]
    return devices if devices else [torch.device('cpu')]

try_gpu(), try_gpu(10), try_all_gpus()
# Out:
# (device(type='cuda', index=0),
#  device(type='cpu'),
#  [device(type='cuda', index=0)])

# %%
x = torch.tensor([1, 2, 3])
x.device
# Out:
# device(type='cpu')

# %%
X = torch.ones(2, 3, device=try_gpu())
X
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]], device='cuda:0')

# %%
Y = torch.rand(2, 3, device=try_gpu(1))
Y
# Out:
# tensor([[0.3481, 0.8256, 0.5163],
#         [0.2644, 0.0625, 0.4796]])

# %%
Z = X.cuda(0)
print(X)
print(Z)
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]], device='cuda:0')
# tensor([[1., 1., 1.],
#         [1., 1., 1.]], device='cuda:0')
